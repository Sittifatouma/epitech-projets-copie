# %%
#import
import pandas as pd

# %%
#import data

timetables = pd.read_csv('dataset/timetables.csv', on_bad_lines='skip')
agency = pd.read_csv('./dataset/data_sncf/agency.txt', on_bad_lines='skip')
calendar_dates = pd.read_csv('./dataset/data_sncf/calendar_dates.txt', on_bad_lines='skip')
calendar = pd.read_csv('./dataset/data_sncf/calendar.txt', on_bad_lines='skip')
routes = pd.read_csv('./dataset/data_sncf/routes.txt', on_bad_lines='skip')
stop_times = pd.read_csv('./dataset/data_sncf/stop_times.txt', on_bad_lines='skip')
stops = pd.read_csv('./dataset/data_sncf/stops.txt', on_bad_lines='skip')
transfers = pd.read_csv('./dataset/data_sncf/transfers.txt', on_bad_lines='skip')
trips = pd.read_csv('./dataset/data_sncf/trips.txt', on_bad_lines='skip')

# %%
# Visualize timetables data

print('timetables data :')
timetables.head()
# Out:
# timetables data :
#                      trip_id  \
# 0      OCESN003100F140147152
# 1      OCESN003190F040047309
# 2      OCESN003300F030037323
# 3      OCESN003198F030037315
# 4      OCESN003371F080087908
# ...                      ...
# 1570                     NaN
# 1571  OCESN895942F0900952655
# 1572  OCESN893301F0200252132
# 1573  OCESN895820F0900952566
# 1574  OCESN895800F0500552541
#
#                                                  trajet      duree
# 0            Gare de Le Havre - Gare de Paris-St-Lazare        138
# 1              Gare de Dieppe - Gare de Paris-St-Lazare        145
# 2           Gare de Cherbourg - Gare de Paris-St-Lazare        194
# 3     Gare de Paris-St-Lazare - Gare de Rouen-Rive-D...         97
# 4     Gare de Paris-St-Lazare - Gare de Trouville-De...        147
# ...                                                 ...        ...
# 1570                                          undefined  undefined
# ...

# %%
# Visualize agency data

print('agency data :')
agency.head()
# Out:
# agency data :
#   agency_id agency_name               agency_url agency_timezone agency_lang
# 0     OCESN        SNCF  http://www.ter-sncf.com    Europe/Paris          fr
# 1     OCENI           -  http://www.ter-sncf.com    Europe/Paris          fr

# %%
# Visualize calendar_dates data

print('calendar_dates data : ')
calendar_dates.head()
# Out:
# calendar_dates data :
#    service_id      date  exception_type
# 0        9939  20200413               2
# 1        8655  20200418               1
# 2        8655  20200516               1
# 3       12563  20200425               1
# 4       12563  20200508               1

# %%
# Visualize calendar data

print('calendar data : v')
calendar.head()
# Out:
# calendar data : v
#    service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0        9939       1        1          1         1       0         0       0
# 1        8655       0        0          0         0       0         1       0
# 2        2341       0        0          0         0       0         1       0
# 3       12564       0        0          0         0       0         0       1
# 4       12565       0        0          0         0       0         1       0
#
#    start_date  end_date
# 0    20200220  20200520
# 1    20200314  20200405
# 2    20200222  20200307
# 3    20200419  20200426
# 4    20200314  20200404

# %%
# Visualize routes data

print('routes data : ')
routes.head()
# Out:
# routes data :
#      route_id agency_id  route_short_name                 route_long_name  \
# 0  OCE1506035     OCESN               NaN     Paris-Vernon-Rouen-Le Havre
# 1  OCE1506037     OCESN               NaN  Paris-Caen-Cherbourg/Trouville
# 2  OCE1506036     OCESN               NaN                 Paris-Granville
# 3  OCE1209987     OCESN               NaN         Paris-Bourges-Montluçon
# 4  OCE1417992     OCESN               NaN                  Paris - Nevers
#
#    route_desc  route_type  route_url  route_color  route_text_color
# 0         NaN           2        NaN          NaN               NaN
# 1         NaN           2        NaN          NaN               NaN
# 2         NaN           2        NaN          NaN               NaN
# 3         NaN           2        NaN          NaN               NaN
# 4         NaN           2        NaN          NaN               NaN

# %%
# Visualize stop_times data

print('stop_times data : ')
stop_times.head()
# Out:
# stop_times data :
#                   trip_id arrival_time departure_time  \
# 0  OCESN037071R0100119847     23:05:00       23:05:00
# 1  OCESN037071R0100119847     23:35:00       23:35:00
# 2  OCESN037071R0100119847     23:55:00       23:55:00
# 3  OCESN037071R0100119847     24:25:00       24:25:00
# 4  OCESN037071R0100119847     24:45:00       24:45:00
#
#                          stop_id  stop_sequence  stop_headsign  pickup_type  \
# 0  StopPoint:OCECar TER-87381509              0            NaN            0
# 1  StopPoint:OCECar TER-87415604              1            NaN            0
# 2  StopPoint:OCECar TER-87415620              2            NaN            0
# 3  StopPoint:OCECar TER-87415877              3            NaN            0
# 4  StopPoint:OCECar TER-87411207              4            NaN            0
#
#    drop_off_type  shape_dist_traveled
# 0              0                  NaN
# 1              0                  NaN
# 2              0                  NaN
# ...

# %%
# Visualize stops data

print('stops data : ')
stops.head()
# Out:
# stops data :
#                 stop_id                 stop_name  stop_desc   stop_lat  \
# 0  StopArea:OCE87381509   Gare de Mantes-la-Jolie        NaN  48.989687
# 1  StopArea:OCE87415604    Gare de Vernon-Giverny        NaN  49.091286
# 2  StopArea:OCE87415620  Gare de Gaillon-Aubevoye        NaN  49.174632
# 3  StopArea:OCE87415877      Gare de Val-de-Reuil        NaN  49.275399
# 4  StopArea:OCE87411207            Gare de Oissel        NaN  49.343042
#
#    stop_lon  zone_id  stop_url  location_type parent_station
# 0  1.703294      NaN       NaN              1            NaN
# 1  1.478363      NaN       NaN              1            NaN
# 2  1.352518      NaN       NaN              1            NaN
# 3  1.224609      NaN       NaN              1            NaN
# 4  1.101821      NaN       NaN              1            NaN

# %%
# Visualize transfers data

print('transfers data : ')
transfers.head()
# Out:
# transfers data :
# Empty DataFrame
# Columns: [from_stop_id, to_stop_id, transfer_type, min_transfer_time]
# Index: []

# %%
# Visualize trips data

print('trips data : ')
trips.head()
# Out:
# trips data :
#      route_id  service_id                     trip_id  trip_headsign  \
# 0  OCE1506035        9939      OCESN037071R0100119847          37071
# 1  OCE1506035        8655       OCESN003191F020027314           3191
# 2  OCE1506035       12563  OCESN003191F06006~NIR54906           3191
# 3  OCE1506035        2341       OCESN003191F010017311           3191
# 4  OCE1506035       12564  OCESN003117F14014~NIR54870           3117
#
#    direction_id  block_id  shape_id
# 0             1       NaN       NaN
# 1             1       NaN       NaN
# 2             1       NaN       NaN
# 3             1       NaN       NaN
# 4             1       NaN       NaN
