# %%
#import
import spacy
from enum import Enum
import numpy as np
from spacy.symbols import PROPN, NOUN, CCONJ, ADP, VERB

# %%
# import test sentences

text_file = open("test_sentences.txt", "r")
lines = text_file.readlines()
test_sentences = []

for l in lines:
  test_sentences.append(l.rstrip())

print('Affichages des 5 premières phrases : ', test_sentences[:5])
print('Nombre total de phrases de test :', len(test_sentences))
text_file.close()
# Out:
# Affichages des 5 premières phrases :  ['De Paris, je vais à Marseille.', 'Je vais à Toulouse pour aller à Lyon.', 'Du Havre, je me rends à Nice.', 'Je me rend à Bordeaux en quittant Strasbourg.', 'De Lille, je vais à Nantes.']
# Nombre total de phrases de test : 100

# %%
class RelationDirection(Enum):
    NONE = 1
    START = 2
    DEST = 3

class RelationStrength(Enum):
    NONE = 1
    WEAK = 2
    STRONG = 3


class WordSense:
    def __init__(self, word: str, direction: RelationDirection, strength: RelationStrength):
        self.word = word
        self.direction = direction
        self.strength = strength

class LinkedWordSense:
    def __init__(self, word: str, fixedWord: str, direction: RelationDirection, strength: RelationStrength):
        self.word = word
        self.fixedWord = fixedWord
        self.direction = direction
        self.strength = strength

CCONJ_Relation = [
    # Départ
    WordSense("depuis",     RelationDirection.START, RelationStrength.STRONG),
    # Destination
    WordSense("puis",       RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("et",         RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("enfin",      RelationDirection.DEST,  RelationStrength.STRONG)
]

NOUN_Relation = [
    # Départ
    WordSense("provenance",     RelationDirection.START, RelationStrength.STRONG),
    # Destination
    WordSense("direction",      RelationDirection.DEST,  RelationStrength.WEAK),
    WordSense("destination",    RelationDirection.DEST,  RelationStrength.WEAK)
]

ADP_FIXED_Relation = [
    # Départ
    LinkedWordSense("à","partir",       RelationDirection.START, RelationStrength.STRONG),
    LinkedWordSense("en", "partant",    RelationDirection.START, RelationStrength.STRONG),
    # Destination
    LinkedWordSense("à","destination",  RelationDirection.DEST,  RelationStrength.STRONG),
    LinkedWordSense("en","direction",   RelationDirection.DEST,  RelationStrength.WEAK)
]
ADP_Relation = [
    # Départ
    WordSense("de",     RelationDirection.START, RelationStrength.STRONG),
    WordSense("du",     RelationDirection.START, RelationStrength.STRONG),
    WordSense("des",    RelationDirection.START, RelationStrength.STRONG),
    WordSense("depuis", RelationDirection.START, RelationStrength.STRONG),
    # Destination
    WordSense("à",      RelationDirection.DEST,  RelationStrength.WEAK),
    WordSense("au",     RelationDirection.DEST,  RelationStrength.WEAK),
    WordSense("aux",    RelationDirection.DEST,  RelationStrength.WEAK),
    WordSense("dans",   RelationDirection.DEST,  RelationStrength.WEAK),
    WordSense("en",     RelationDirection.DEST,  RelationStrength.WEAK),
    WordSense("par",    RelationDirection.DEST,  RelationStrength.WEAK)
] 

VERB_MARK_Relation = [
    WordSense("après",   RelationDirection.START, RelationStrength.WEAK),
    WordSense("avant",   RelationDirection.DEST, RelationStrength.STRONG),
    WordSense("de",   RelationDirection.START, RelationStrength.STRONG),
]
VERB_Relation = [
    # Départ
    WordSense("décoller",   RelationDirection.START, RelationStrength.STRONG),
    WordSense("passer",     RelationDirection.START, RelationStrength.WEAK),
    WordSense("être",       RelationDirection.START, RelationStrength.STRONG),
    WordSense("quitter", RelationDirection.START, RelationStrength.STRONG),
    WordSense("entre", RelationDirection.START, RelationStrength.STRONG),
    # Destination
    WordSense("arriver",    RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("aller",      RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("visiter",    RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("atterrir",   RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("découvrir",  RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("voyager",    RelationDirection.DEST,  RelationStrength.STRONG),
    WordSense("rendre",     RelationDirection.DEST,  RelationStrength.STRONG)
]

def analyseSentence(sentence):
    print(f"Phrase : {sentence}")
    nlp = spacy.load("fr_core_news_sm")
    doc = nlp(sentence)
    locations = []
    fullTrip = []

    for i in doc.ents:
        if i.label_ == 'LOC' or i.label_ == 'GPE': 
            locations.append(i.text)
    print(f"Localisations trouvés: {locations}")

    if len(locations) <= 1:
        print("Cannot parse request or invalid request.")
    else:
        tokens = np.zeros(len(locations), dtype=object)
        for i in range(len(locations)):
            tokenFound = False
            for token in doc:
                if token.pos == PROPN:
                    isUsable = True
                    for tokenSelected in tokens:
                        if type(tokenSelected) != int and tokenSelected == token:
                            isUsable = False
                    if isUsable:
                        if token.text in locations[i]:
                            tokens[i] = token
                            tokenFound = True
                            break

            if tokenFound == False:
                for token in doc:
                    if token.pos == NOUN:
                        isUsable = True
                        for tokenSelected in tokens:
                            if type(tokenSelected) != int and tokenSelected == token:
                                isUsable = False
                        if isUsable:
                            if token.text in locations[i]:
                                tokens[i] = token
                                tokenFound = True
                                break

            if tokenFound == False:
                for token in doc:
                    isUsable = True
                    for tokenSelected in tokens:
                        if type(tokenSelected) != int and tokenSelected == token:
                            isUsable = False
                    if isUsable:
                        if token.text in locations[i]:
                            tokens[i] = token
                            tokenFound = True
                            break

            if tokenFound == False:
                print(f"Localization {locations[i]} not found")
                tokens[i] = None

        tmpTokens = tokens
        tokens = [] 
        for token in tmpTokens: 
            if token != None : 
                tokens.append(token)


        weighedTokens = np.zeros(len(tokens), dtype=object)
        for i in range(len(tokens)):
            foundWeight = []
            parent = tokens[i].head

            for child in tokens[i].children:
                if child.pos == CCONJ:
                    for ref in CCONJ_Relation:
                        if ref.word == child.lemma_:
                            foundWeight.append(ref)
                            break

            if len(foundWeight) <= 0:
                if parent.pos == NOUN:
                    for ref in NOUN_Relation:
                        if ref.word == parent.lemma_:
                            foundWeight.append(ref)
                            break

            if len(foundWeight) <= 0:
                for child in tokens[i].children:
                    if child.pos == ADP:
                        for subChild in child.children:
                            if subChild.dep_ == 'fixed':
                                for ref in ADP_FIXED_Relation:
                                    if ref.word == child.lemma_ and ref.fixedWord == subChild.lemma_:
                                        foundWeight.append(ref)
                                        break

                
                    
            if len(foundWeight) <= 0:
                for child in tokens[i].children:
                    for ref in ADP_Relation:
                        if ref.word == child.lemma_:
                            foundWeight.append(ref)
                            break

            if len(foundWeight) <= 1:
                if parent.pos == VERB:
                    for child in parent.children:
                        if child.dep_ == 'mark' and child.pos == ADP:
                            for ref in VERB_MARK_Relation:
                                if ref.word == child.lemma_:
                                    foundWeight.append(ref)
                                    break
                
            if len(foundWeight) <= 1:
                for ref in VERB_Relation:
                    if ref.word == parent.lemma_:
                        foundWeight.append(ref)
                        break

            if len(foundWeight) == 0:
                foundWeight.append(WordSense("default", RelationDirection.DEST,  RelationStrength.WEAK))

            
            selectedWeight = None
            for j in range(len(foundWeight)):
                if foundWeight[j].strength == RelationStrength.STRONG:
                    selectedWeight = foundWeight[j]
                    break
            if selectedWeight is None:
                selectedWeight = foundWeight[0]

            weighedTokens[i] = (tokens[i], selectedWeight)


        orderedTokens = []
        numberOfStrongStrength = 0
        for i in range(len(weighedTokens)):
            token, weight = weighedTokens[i]
            if weight.direction == RelationDirection.START:
                if weight.strength == RelationStrength.STRONG:
                    orderedTokens.insert(numberOfStrongStrength, token)
                    numberOfStrongStrength = numberOfStrongStrength + 1
                else:
                    orderedTokens.append(token)
        

        numberOfStrongStrength = 0
        for i in range(len(weighedTokens)):
            token, weight = weighedTokens[i]
            if weight.direction == RelationDirection.DEST:
                if weight.strength == RelationStrength.STRONG:
                    orderedTokens.append(token)
                    numberOfStrongStrength = numberOfStrongStrength + 1
                else:
                    if numberOfStrongStrength == 0:
                        orderedTokens.append(token)
                    else:
                        orderedTokens.insert(len(orderedTokens)-numberOfStrongStrength, token)

        for token in orderedTokens:
            fullTrip.append(token.text)

        return fullTrip

def testNLP(sentence):
      result = analyseSentence(sentence)
      print(f"résultat:    {result} \n")
# testNLP('Je veux partir de Montpellier pour aller à Paris en passant par Bordeaux.')

# %%
# test sentence

for sentence in test_sentences:
  testNLP(sentence)
# Out:
# Phrase : De Paris, je vais à Marseille.
# Localisations trouvés: ['Paris', 'Marseille']
# résultat:    ['Paris', 'Marseille']
#
# Phrase : Je vais à Toulouse pour aller à Lyon.
# Localisations trouvés: ['Toulouse', 'Lyon']
# résultat:    ['Toulouse', 'Lyon']
#
# Phrase : Du Havre, je me rends à Nice.
# Localisations trouvés: ['Du Havre', 'Nice']
# résultat:    ['Havre', 'Nice']
#
# Phrase : Je me rend à Bordeaux en quittant Strasbourg.
# Localisations trouvés: ['Bordeaux', 'Strasbourg']
# résultat:    ['Strasbourg', 'Bordeaux']
#
# Phrase : De Lille, je vais à Nantes.
# Localisations trouvés: ['De Lille', 'Nantes']
# résultat:    ['Lille', 'Nantes']
#
# Phrase : Je pars de Montpellier pour aller à Rennes.
# Localisations trouvés: ['Montpellier', 'Rennes']
# résultat:    ['Montpellier', 'Rennes']
#
# Phrase : De Toulon, je me rends à Grenoble.
# Localisations trouvés: ['Toulon', 'Grenoble']
# résultat:    ['Toulon', 'Grenoble']
#
# Phrase : Je quitte Rouen pour me rendre à Perpignan.
# Localisations trouvés: ['Rouen', 'Perpignan']
# résultat:    ['Rouen', 'Perpignan']
#
# Phrase : De Dijon, je vais à Le Mans.
# Localisations trouvés: ['Dijon', 'Le Mans']
# résultat:    ['Dijon', 'Mans']
#
# Phrase : Je pars à Mulhouse de Rennes.
# Localisations trouvés: ['Mulhouse', 'Rennes']
# résultat:    ['Rennes', 'Mulhouse']
#
# Phrase : De Limoges, je me rends à Clermont-Ferrand.
# Localisations trouvés: ['Limoges', 'Clermont-Ferrand']
# résultat:    ['Limoges', 'Clermont']
#
# Phrase : Je quitte Nantes pour me rendre à Caen.
# Localisations trouvés: ['Nantes', 'Caen']
# résultat:    ['Nantes', 'Caen']
#
# Phrase : De Reims, je vais à Toulouse.
# Localisations trouvés: ['Reims', 'Toulouse']
# résultat:    ['Reims', 'Toulouse']
#
# Phrase : Je pars de Grenoble pour aller à Le Havre.
# Localisations trouvés: ['Grenoble', 'Le Havre']
# résultat:    ['Grenoble', 'Havre']
#
# Phrase : Je me rends à Rouen de Bordeaux.
# Localisations trouvés: ['Rouen de Bordeaux']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je quitte Toulouse pour me rendre à Metz.
# Localisations trouvés: ['Toulouse', 'Metz']
# résultat:    ['Toulouse', 'Metz']
#
# Phrase : De Nice, je vais à Caen.
# Localisations trouvés: ['Caen']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je pars de Montpellier pour aller à Le Mans.
# Localisations trouvés: ['Montpellier', 'Le Mans']
# résultat:    ['Montpellier', 'Mans']
#
# Phrase : De Brest, je me rends à Dijon.
# Localisations trouvés: ['Brest', 'Dijon']
# résultat:    ['Brest', 'Dijon']
#
# Phrase : Je me rend à Lille et je vais quitter Perpignan.
# Localisations trouvés: ['Lille', 'Perpignan']
# résultat:    ['Perpignan', 'Lille']
#
# Phrase : De Mulhouse, je vais à Reims.
# Localisations trouvés: ['Reims']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je pars de Biarritz pour aller à Limoges.
# Localisations trouvés: ['Biarritz', 'Limoges']
# résultat:    ['Biarritz', 'Limoges']
#
# Phrase : De Aix-en-Provence, je me rends à Toulon.
# Localisations trouvés: ['Toulon']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je quitte Le Mans pour me rendre à Caen.
# Localisations trouvés: ['Le Mans', 'Caen']
# résultat:    ['Mans', 'Caen']
#
# Phrase : Je vais à Dijon de Clermont-Ferrand.
# Localisations trouvés: ['Dijon', 'Clermont-Ferrand']
# résultat:    ['Clermont', 'Dijon']
#
# Phrase : Je pars de Bordeaux pour aller à Le Havre.
# Localisations trouvés: ['Bordeaux', 'Le Havre']
# résultat:    ['Bordeaux', 'Havre']
#
# Phrase : Je me rends à Brest de Orléans.
# Localisations trouvés: ['Brest', 'Orléans']
# résultat:    ['Orléans', 'Brest']
#
# Phrase : Je quitte Caen pour me rendre à Mulhouse.
# Localisations trouvés: ['Caen', 'Mulhouse']
# résultat:    ['Caen', 'Mulhouse']
#
# Phrase : De Marseille, je vais à Le Mans.
# Localisations trouvés: ['Marseille', 'Le Mans']
# résultat:    ['Marseille', 'Mans']
#
# Phrase : Je pars à Lyon en partant de Perpignan.
# Localisations trouvés: ['Lyon', 'Perpignan']
# résultat:    ['Perpignan', 'Lyon']
#
# Phrase : De Bordeaux, je me rends à Rouen.
# Localisations trouvés: ['Bordeaux', 'Rouen']
# résultat:    ['Bordeaux', 'Rouen']
#
# Phrase : Je quitte Toulouse pour me rendre à Metz.
# Localisations trouvés: ['Toulouse', 'Metz']
# résultat:    ['Toulouse', 'Metz']
#
# Phrase : Je vais à Cannes depuis Nice.
# Localisations trouvés: ['Cannes', 'Nice']
# résultat:    ['Nice', 'Cannes']
#
# Phrase : Je pars de Montpellier pour aller à Le Mans.
# Localisations trouvés: ['Montpellier', 'Le Mans']
# résultat:    ['Montpellier', 'Mans']
#
# Phrase : De Brest, je me rends à Dijon.
# Localisations trouvés: ['Brest', 'Dijon']
# résultat:    ['Brest', 'Dijon']
#
# Phrase : Je quitte Perpignan pour me rendre à Lille.
# Localisations trouvés: ['Perpignan', 'Lille']
# résultat:    ['Perpignan', 'Lille']
#
# Phrase : De Mulhouse, je vais à Reims.
# Localisations trouvés: ['Reims']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je pars de Biarritz pour aller à Limoges.
# Localisations trouvés: ['Biarritz', 'Limoges']
# résultat:    ['Biarritz', 'Limoges']
#
# Phrase : De Aix-en-Provence, je me rends à Toulon.
# Localisations trouvés: ['Toulon']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je quitte Le Mans pour me rendre à Caen.
# Localisations trouvés: ['Le Mans', 'Caen']
# résultat:    ['Mans', 'Caen']
#
# Phrase : De Clermont-Ferrand, je vais à Dijon.
# Localisations trouvés: ['Dijon']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je pars de Ajaccio pour aller à Le Havre.
# Localisations trouvés: ['Ajaccio', 'Le Havre']
# résultat:    ['Ajaccio', 'Havre']
#
# Phrase : De Orléans, je me rends à Brest.
# Localisations trouvés: ['Brest']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je quitte Caen pour me rendre à Mulhouse.
# Localisations trouvés: ['Caen', 'Mulhouse']
# résultat:    ['Caen', 'Mulhouse']
#
# Phrase : De Marseille, je vais à Le Mans.
# Localisations trouvés: ['Marseille', 'Le Mans']
# résultat:    ['Marseille', 'Mans']
#
# Phrase : De Paris, je vais à Nice.
# Localisations trouvés: ['Paris', 'Nice']
# résultat:    ['Paris', 'Nice']
#
# Phrase : Je pars de Toulouse pour aller à Marseille.
# Localisations trouvés: ['Toulouse', 'Marseille']
# résultat:    ['Toulouse', 'Marseille']
#
# Phrase : De Bordeaux, je me rends à Lyon.
# Localisations trouvés: ['Bordeaux', 'Lyon']
# résultat:    ['Bordeaux', 'Lyon']
#
# Phrase : Je quitte Grenoble pour me rendre à Nantes.
# Localisations trouvés: ['Grenoble', 'Nantes']
# résultat:    ['Grenoble', 'Nantes']
#
# Phrase : De Lille, je vais à Montpellier.
# Localisations trouvés: ['De Lille', 'Montpellier']
# résultat:    ['Lille', 'Montpellier']
#
# Phrase : De Marseille, je vais à Nice en passant par Aix-en-Provence.
# Localisations trouvés: ['Marseille', 'Nice', 'Aix-en-Provence']
# résultat:    ['Marseille', 'Aix-en-Provence', 'Nice']
#
# Phrase : Je pars de Lille pour aller à Bordeaux, en faisant escale à Toulouse.
# Localisations trouvés: ['de Lille', 'Bordeaux', 'Toulouse']
# résultat:    ['Lille', 'Toulouse', 'Bordeaux']
#
# Phrase : Du Havre, je me rends à Grenoble en passant par Paris.
# Localisations trouvés: ['Du Havre', 'Grenoble', 'Paris']
# résultat:    ['Havre', 'Paris', 'Grenoble']
#
# Phrase : Je quitte Strasbourg pour me rendre à Nantes, en passant par Tours.
# Localisations trouvés: ['Strasbourg', 'Nantes', 'Tours']
# résultat:    ['Strasbourg', 'Tours', 'Nantes']
#
# Phrase : De Lyon, je vais à Perpignan en passant par Montpellier.
# Localisations trouvés: ['Lyon', 'Perpignan', 'Montpellier']
# résultat:    ['Lyon', 'Montpellier', 'Perpignan']
#
# Phrase : Je pars de Metz pour aller à Brest, en faisant escale à Rennes.
# Localisations trouvés: ['Brest', 'Rennes']
# résultat:    ['Rennes', 'Brest']
#
# Phrase : De Toulon, je me rends à Biarritz en passant par Marseille.
# Localisations trouvés: ['Toulon', 'Biarritz', 'Marseille']
# résultat:    ['Toulon', 'Marseille', 'Biarritz']
#
# Phrase : Je quitte Rouen pour me rendre à Ajaccio, en passant par Nice.
# Localisations trouvés: ['Rouen', 'Ajaccio', 'Nice']
# résultat:    ['Rouen', 'Nice', 'Ajaccio']
#
# Phrase : De Dijon, je vais à Saint-Denis en passant par Lyon.
# Localisations trouvés: ['Dijon', 'Saint-Denis', 'Lyon']
# résultat:    ['Dijon', 'Lyon', 'Saint-Denis']
#
# Phrase : Je pars de Rennes pour aller à Mulhouse, en faisant escale à Strasbourg.
# Localisations trouvés: ['Rennes', 'Mulhouse', 'Strasbourg']
# résultat:    ['Rennes', 'Strasbourg', 'Mulhouse']
#
# Phrase : De Limoges, je me rends à Clermont-Ferrand en passant par Orléans.
# Localisations trouvés: ['Limoges', 'Clermont-Ferrand', 'Orléans']
# résultat:    ['Limoges', 'Orléans', 'Clermont']
#
# Phrase : Je quitte Nantes pour me rendre à Nice, en passant par Marseille.
# Localisations trouvés: ['Nantes', 'Nice', 'Marseille']
# résultat:    ['Nantes', 'Marseille', 'Nice']
#
# Phrase : De Reims, je vais à Toulouse en passant par Lyon.
# Localisations trouvés: ['Reims', 'Toulouse', 'Lyon']
# résultat:    ['Reims', 'Lyon', 'Toulouse']
#
# Phrase : Je pars de Grenoble pour aller à Le Havre, en faisant escale à Paris.
# Localisations trouvés: ['Grenoble', 'Le Havre', 'Paris']
# résultat:    ['Grenoble', 'Paris', 'Havre']
#
# Phrase : De Bordeaux, je me rends à Rouen en passant par Nantes.
# Localisations trouvés: ['Bordeaux', 'Rouen', 'Nantes']
# résultat:    ['Bordeaux', 'Nantes', 'Rouen']
#
# Phrase : Je quitte Toulouse pour me rendre à Metz, en passant par Clermont-Ferrand.
# Localisations trouvés: ['Toulouse', 'Metz', 'Clermont-Ferrand']
# résultat:    ['Toulouse', 'Clermont', 'Metz']
#
# Phrase : De Nice, je vais à Caen en passant par Rouen.
# Localisations trouvés: ['Rouen']
# Cannot parse request or invalid request.
# résultat:    None
#
# Phrase : Je pars de Montpellier pour aller à Le Mans, en faisant escale à Tours.
# Localisations trouvés: ['Montpellier', 'Le Mans', 'Tours']
# résultat:    ['Montpellier', 'Tours', 'Mans']
#
# Phrase : De Brest, je me rends à Dijon en passant par Rennes.
# Localisations trouvés: ['Brest', 'Dijon', 'Rennes']
# résultat:    ['Brest', 'Rennes', 'Dijon']
#
# Phrase : Je quitte Perpignan pour me rendre à Lille, en passant par Toulouse.
# Localisations trouvés: ['Perpignan', 'Lille', 'Toulouse']
# résultat:    ['Perpignan', 'Toulouse', 'Lille']
#
# Phrase : De Mulhouse, je vais à Reims en passant par Strasbourg.
# Localisations trouvés: ['Reims', 'Strasbourg']
# résultat:    ['Strasbourg', 'Reims']
#
# Phrase : Je pars de Biarritz pour aller à Limoges, en faisant escale à Bordeaux.
# Localisations trouvés: ['Biarritz', 'Limoges', 'Bordeaux']
# résultat:    ['Biarritz', 'Bordeaux', 'Limoges']
#
# Phrase : De Aix-en-Provence, je me rends à Toulon en passant par Marseille.
# Localisations trouvés: ['Toulon', 'Marseille']
# résultat:    ['Toulon', 'Marseille']
#
# Phrase : Je quitte Le Mans pour me rendre à Caen, en passant par Orléans.
# Localisations trouvés: ['Le Mans', 'Caen', 'Orléans']
# résultat:    ['Mans', 'Orléans', 'Caen']
#
# Phrase : De Clermont-Ferrand, je vais à Dijon en passant par Lyon.
# Localisations trouvés: ['Dijon', 'Lyon']
# résultat:    ['Lyon', 'Dijon']
#
# Phrase : Je pars de Ajaccio pour aller à Le Havre, en faisant escale à Nice.
# Localisations trouvés: ['Ajaccio', 'Le Havre', 'Nice']
# résultat:    ['Ajaccio', 'Nice', 'Havre']
#
# Phrase : De Orléans, je me rends à Brest en passant par Rennes.
# Localisations trouvés: ['Brest', 'Rennes']
# résultat:    ['Rennes', 'Brest']
#
# Phrase : Je quitte Caen pour me rendre à Mulhouse, en passant par Reims.
# Localisations trouvés: ['Caen', 'Mulhouse', 'Reims']
# résultat:    ['Caen', 'Reims', 'Mulhouse']
#
# Phrase : De Marseille, je vais à Le Mans en passant par Nantes.
# Localisations trouvés: ['Marseille', 'Le Mans', 'Nantes']
# résultat:    ['Marseille', 'Nantes', 'Mans']
#
# Phrase : Je pars de Lyon pour aller à Perpignan, en faisant escale à Montpellier.
# Localisations trouvés: ['pars de Lyon', 'Perpignan', 'Montpellier']
# résultat:    ['Lyon', 'Montpellier', 'Perpignan']
#
# Phrase : De Cannes, je vais à Lille en passant par Lyon.
# Localisations trouvés: ['Lille', 'Lyon']
# résultat:    ['Lyon', 'Lille']
#
# Phrase : Je pars de Marseille pour aller à Nantes, en faisant escale à Bordeaux.
# Localisations trouvés: ['Marseille', 'Nantes', 'Bordeaux']
# résultat:    ['Marseille', 'Bordeaux', 'Nantes']
#
# Phrase : De Toulouse, je me rends à Nice en passant par Marseille.
# Localisations trouvés: ['Toulouse', 'Nice', 'Marseille']
# résultat:    ['Toulouse', 'Marseille', 'Nice']
#
# Phrase : Je quitte Grenoble pour me rendre à Rouen, en passant par Lyon.
# Localisations trouvés: ['Grenoble', 'Rouen', 'Lyon']
# résultat:    ['Grenoble', 'Lyon', 'Rouen']
#
# Phrase : De Dijon, je vais à Mulhouse en passant par Strasbourg.
# Localisations trouvés: ['Dijon', 'Mulhouse', 'Strasbourg']
# résultat:    ['Dijon', 'Strasbourg', 'Mulhouse']
#
# Phrase : Je pars de Bordeaux pour aller à Metz, en faisant escale à Toulouse.
# Localisations trouvés: ['Bordeaux', 'Metz', 'Toulouse']
# résultat:    ['Bordeaux', 'Toulouse', 'Metz']
#
# Phrase : De Perpignan, je me rends à Reims en passant par Montpellier.
# Localisations trouvés: ['Reims', 'Montpellier']
# résultat:    ['Montpellier', 'Reims']
#
# Phrase : Je quitte Le Havre pour me rendre à Clermont-Ferrand, en passant par Orléans.
# Localisations trouvés: ['Le Havre', 'Clermont-Ferrand', 'Orléans']
# résultat:    ['Havre', 'Orléans', 'Clermont']
#
# Phrase : De Rennes, je vais à Ajaccio en passant par Marseille.
# Localisations trouvés: ['Rennes', 'Ajaccio', 'Marseille']
# résultat:    ['Rennes', 'Marseille', 'Ajaccio']
#
# Phrase : Je pars de Nice pour aller à Le Mans, en faisant escale à Nantes.
# Localisations trouvés: ['Nice', 'Le Mans', 'Nantes']
# résultat:    ['Nice', 'Nantes', 'Mans']
#
# Phrase : De Montpellier, je me rends à Brest en passant par Rennes.
# Localisations trouvés: ['Montpellier', 'Brest', 'Rennes']
# résultat:    ['Montpellier', 'Rennes', 'Brest']
#
# Phrase : Je quitte Lyon pour me rendre à Toulon, en passant par Aix-en-Provence.
# Localisations trouvés: ['Lyon', 'Toulon', 'Aix-en-Provence']
# résultat:    ['Lyon', 'Aix-en-Provence', 'Toulon']
#
# Phrase : De Marseille, je vais à Le Havre en passant par Rouen.
# Localisations trouvés: ['Marseille', 'Le Havre', 'Rouen']
# résultat:    ['Marseille', 'Rouen', 'Havre']
#
# Phrase : Je pars de Grenoble pour aller à Dijon, en faisant escale à Lyon.
# Localisations trouvés: ['Grenoble', 'Dijon', 'Lyon']
# résultat:    ['Grenoble', 'Lyon', 'Dijon']
#
# Phrase : De Toulouse, je me rends à Cannes en passant par Nice.
# Localisations trouvés: ['Toulouse', 'Cannes', 'Nice']
# résultat:    ['Toulouse', 'Nice', 'Cannes']
#
# Phrase : Je quitte Perpignan pour me rendre à Lille, en passant par Toulouse.
# Localisations trouvés: ['Perpignan', 'Lille', 'Toulouse']
# résultat:    ['Perpignan', 'Toulouse', 'Lille']
#
# Phrase : De Bordeaux, je vais à Mulhouse en passant par Strasbourg.
# Localisations trouvés: ['Bordeaux', 'Mulhouse', 'Strasbourg']
# résultat:    ['Bordeaux', 'Strasbourg', 'Mulhouse']
#
# Phrase : Je pars de Nantes pour aller à Reims, en faisant escale à Orléans.
# Localisations trouvés: ['Reims', 'Orléans']
# résultat:    ['Orléans', 'Reims']
#
# Phrase : De Clermont-Ferrand, je me rends à Ajaccio en passant par Marseille.
# Localisations trouvés: ['Ajaccio', 'Marseille']
# résultat:    ['Marseille', 'Ajaccio']
#
# Phrase : Je quitte Le Mans pour me rendre à Montpellier, en passant par Tours.
# Localisations trouvés: ['Le Mans', 'Montpellier', 'Tours']
# résultat:    ['Mans', 'Tours', 'Montpellier']
